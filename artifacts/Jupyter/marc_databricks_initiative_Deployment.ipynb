# %%
# CleanseHeader
spark.sql("CREATE DATABASE IF NOT EXISTS `{marc_databricks_initiative#cleanse#database_name}` LOCATION '{marc_databricks_initiative#cleanse#database_directory}'")

# %%
# CoreHeader
spark.sql("CREATE DATABASE IF NOT EXISTS `{marc_databricks_initiative#core#database_name}` LOCATION '{marc_databricks_initiative#core#database_directory}'")

# %%
# MartHeader
spark.sql("CREATE DATABASE IF NOT EXISTS `{marc_databricks_initiative#mart#database_name}` LOCATION '{marc_databricks_initiative#mart#database_directory}'")

# %%
# StageHeader
spark.sql("CREATE DATABASE IF NOT EXISTS `{marc_databricks_initiative#stage#database_name}` LOCATION '{marc_databricks_initiative#stage#database_directory}'")

# %%
# StageTable: customer_order_products_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`order_id` Integer NOT NULL
    ,`order_tms` Timestamp NOT NULL
    ,`order_status` String NOT NULL
    ,`customer_id` Integer NOT NULL
    ,`email_address` String NOT NULL
    ,`full_name` String NOT NULL
    ,`order_total` Decimal(38,2)
    ,`items` String
)
USING delta
"""
)

# %%
# StageSourceView: customer_order_products_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`order_id` AS `order_id`
    ,`s1`.`order_tms` AS `order_tms`
    ,`s1`.`order_status` AS `order_status`
    ,`s1`.`customer_id` AS `customer_id`
    ,`s1`.`email_address` AS `email_address`
    ,`s1`.`full_name` AS `full_name`
    ,`s1`.`order_total` AS `order_total`
    ,`s1`.`items` AS `items`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`customer_order_products` AS `s1`
""")

# %%
# StageResultView: customer_order_products_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`order_id` AS `order_id`
    ,`bg_source`.`order_tms` AS `order_tms`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address` AS `email_address`
    ,`bg_source`.`full_name` AS `full_name`
    ,`bg_source`.`order_total` AS `order_total`
    ,`bg_source`.`items` AS `items`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products` AS `bg_source`
""")

# %%
# StageTable: customer_order_products1_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products1`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products1` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`order_id` Integer NOT NULL
    ,`order_tms` Timestamp NOT NULL
    ,`order_status` String NOT NULL
    ,`customer_id` Integer NOT NULL
    ,`email_address` String NOT NULL
    ,`full_name` String NOT NULL
    ,`order_total` Decimal(38,2)
    ,`items` String
)
USING delta
"""
)

# %%
# StageSourceView: customer_order_products1_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products1_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`order_id` AS `order_id`
    ,`s1`.`order_tms` AS `order_tms`
    ,`s1`.`order_status` AS `order_status`
    ,`s1`.`customer_id` AS `customer_id`
    ,`s1`.`email_address` AS `email_address`
    ,`s1`.`full_name` AS `full_name`
    ,`s1`.`order_total` AS `order_total`
    ,`s1`.`items` AS `items`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`customer_order_products` AS `s1`
""")

# %%
# StageResultView: customer_order_products1_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products1_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`order_id` AS `order_id`
    ,`bg_source`.`order_tms` AS `order_tms`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address` AS `email_address`
    ,`bg_source`.`full_name` AS `full_name`
    ,`bg_source`.`order_total` AS `order_total`
    ,`bg_source`.`items` AS `items`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products1` AS `bg_source`
""")

# %%
# EntityCleanseTable: Ent_orders_Entity Cleanse Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_orders`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_orders` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp
    ,`bg_errorcount` Integer NOT NULL
    ,`bg_effectivetimestamp` Timestamp
    ,`bg_cleanse_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`order_id` Integer
    ,`order_status` String
    ,`order_total` Decimal(38,2)
)
USING delta
"""
)

# %%
# EntityCleanseError: Ent_orders_Entity Cleanse Error_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_orders_error`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_orders_error` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp
    ,`bg_errorcount` Integer NOT NULL
    ,`bg_errordescription` String
    ,`bg_effectivetimestamp` Timestamp
    ,`bg_cleanse_id` Long NOT NULL
    ,`order_id` Integer
    ,`order_status` String
    ,`order_total` Decimal(38,2)
)
USING delta
"""
)

# %%
# EntitySourceView: Ent_orders_Entity Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_orders_source`
AS
SELECT
     CAST(NULL AS String) AS `bg_sourcesystem`
    ,current_timestamp() AS `bg_effectivetimestamp`
    ,`s1`.`order_id` AS `order_id`
    ,`s1`.`order_status` AS `order_status`
    ,`s1`.`order_total` AS `order_total`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products1_result` AS `s1`
""")

# %%
# EntityIntermediateCleanseResultView: Ent_orders_Entity Cleanse IntermediateResult View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_orders_result`
AS
SELECT
     `bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`order_id` AS `order_id`
    ,`order_status` AS `order_status`
    ,`order_total` AS `order_total`
FROM `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_orders`
WHERE `bg_errorcount` = 0
""")

# %%
# EntityCoreTable: Ent_orders_Entity Core Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_updatetimestamp` Timestamp NOT NULL
    ,`ent_orders_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`order_id` Integer NOT NULL
    ,`order_status` String NOT NULL
    ,`order_total` Decimal(38,2) NOT NULL
)
USING delta
"""
)
result_df = spark.sql(f"""
INSERT
INTO `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders` (
     `bg_sourcesystem`
    ,`bg_loadtimestamp`
    ,`bg_updatetimestamp`
    ,`ent_orders_id`
    ,`order_id`
    ,`order_status`
    ,`order_total`
)
SELECT
     'Unknown' AS `bg_sourcesystem`
    ,'1900-01-01' AS `bg_loadtimestamp`
    ,'1900-01-01' AS `bg_updatetimestamp`
    ,-1 AS `ent_orders_id`
    ,0 AS `order_id`
    ,'Unknown' AS `order_status`
    ,0 AS `order_total`
""")

# %%
# EntityLookupView: Ent_orders_Entity Lookup View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders_lookup`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`bg_source`.`order_id` AS `order_id`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`order_total` AS `order_total`
FROM `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_orders_result` AS `bg_source`
""")

# %%
# EntityResultView: Ent_orders_Entity Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders_result`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_updatetimestamp` AS `bg_updatetimestamp`
    ,`bg_source`.`ent_orders_id` AS `ent_orders_id`
    ,`bg_source`.`order_id` AS `order_id`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`order_total` AS `order_total`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders` AS `bg_source`
""")

# %%
# EntityDeltaView: Ent_orders_Entity Delta View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders_delta`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`order_id` AS `order_id`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`order_total` AS `order_total`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders_lookup` AS `bg_source`
LEFT OUTER JOIN `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders_result` AS `bg_target`
   ON (`bg_source`.`order_id` = `bg_target`.`order_id`)
  AND (`bg_source`.`order_status` = `bg_target`.`order_status`)
  AND (`bg_source`.`order_total` = `bg_target`.`order_total`)
WHERE `bg_target`.`ent_orders_id` IS NULL
""")

# %%
# MartDimensionTable: Ent_orders_Mart Dimension Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_rowhash` String
    ,`ent_orders_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`order_id` Integer NOT NULL
)
USING delta
"""
)
result_df = spark.sql(f"""
INSERT
INTO `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders` (
     `bg_sourcesystem`
    ,`bg_loadtimestamp`
    ,`bg_rowhash`
    ,`ent_orders_id`
    ,`order_id`
)
SELECT
     'Unknown' AS `bg_sourcesystem`
    ,'1900-01-01' AS `bg_loadtimestamp`
    ,'0' AS `bg_rowhash`
    ,-1 AS `ent_orders_id`
    ,0 AS `order_id`
""")

# %%
# MartDimensionSourceView: Ent_orders_Mart Dimension Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders_source`
AS
SELECT
     CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`order_id` AS `order_id`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders_result` AS `s1`
""")

# %%
# MartDimensionHashingView: Ent_orders_Mart Dimension Hashing View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders_hashing`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,'0' AS `bg_rowhash`
    ,`bg_source`.`order_id` AS `order_id`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders_source` AS `bg_source`
""")

# %%
# MartDimensionResultView: Ent_orders_Mart Dimension Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders_result`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_rowhash` AS `bg_rowhash`
    ,`bg_source`.`ent_orders_id` AS `ent_orders_id`
    ,`bg_source`.`order_id` AS `order_id`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders` AS `bg_source`
""")

# %%
# MartDimensionDeltaView: Ent_orders_Mart Dimension Delta View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders_delta`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_rowhash` AS `bg_rowhash`
    ,`bg_source`.`order_id` AS `order_id`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders_hashing` AS `bg_source`
LEFT OUTER JOIN `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders_result` AS `bg_target`
   ON (`bg_source`.`order_id` = `bg_target`.`order_id`)
  AND (`bg_source`.`bg_rowhash` = `bg_target`.`bg_rowhash`)
WHERE `bg_target`.`ent_orders_id` IS NULL
""")

# %%
# StageTable: customers_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`customer_id` Integer NOT NULL
    ,`email_address` String NOT NULL
    ,`full_name` String NOT NULL
)
USING delta
"""
)

# %%
# StageSourceView: customers_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`customer_id` AS `customer_id`
    ,`s1`.`email_address` AS `email_address`
    ,`s1`.`full_name` AS `full_name`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`customers` AS `s1`
""")

# %%
# StageResultView: customers_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address` AS `email_address`
    ,`bg_source`.`full_name` AS `full_name`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers` AS `bg_source`
""")

# %%
# EntityCleanseTable: Ent_customers_Entity Cleanse Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_customers`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_customers` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp
    ,`bg_errorcount` Integer NOT NULL
    ,`bg_effectivetimestamp` Timestamp
    ,`bg_cleanse_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`customer_id` Integer
    ,`email_address` String
    ,`full_name` String
    ,`email_address1` String
    ,`full_name1` String
)
USING delta
"""
)

# %%
# EntityCleanseError: Ent_customers_Entity Cleanse Error_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_customers_error`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_customers_error` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp
    ,`bg_errorcount` Integer NOT NULL
    ,`bg_errordescription` String
    ,`bg_effectivetimestamp` Timestamp
    ,`bg_cleanse_id` Long NOT NULL
    ,`customer_id` Integer
    ,`email_address` String
    ,`full_name` String
    ,`email_address1` String
    ,`full_name1` String
)
USING delta
"""
)

# %%
# EntitySourceView: Ent_customers_Entity Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_customers_source`
AS
SELECT
     CAST(NULL AS String) AS `bg_sourcesystem`
    ,current_timestamp() AS `bg_effectivetimestamp`
    ,`s1`.`customer_id` AS `customer_id`
    ,`s1`.`email_address` AS `email_address`
    ,`s1`.`full_name` AS `full_name`
    ,`s1`.`email_address` AS `email_address1`
    ,`s1`.`full_name` AS `full_name1`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_result` AS `s1`
""")

# %%
# EntityIntermediateCleanseResultView: Ent_customers_Entity Cleanse IntermediateResult View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_customers_result`
AS
SELECT
     `bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`customer_id` AS `customer_id`
    ,`email_address` AS `email_address`
    ,`full_name` AS `full_name`
    ,`email_address1` AS `email_address1`
    ,`full_name1` AS `full_name1`
FROM `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_customers`
WHERE `bg_errorcount` = 0
""")

# %%
# EntityCoreTable: Ent_customers_Entity Core Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_updatetimestamp` Timestamp NOT NULL
    ,`ent_customers_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`customer_id` Integer NOT NULL
    ,`email_address` String NOT NULL
    ,`full_name` String NOT NULL
    ,`email_address1` String NOT NULL
    ,`full_name1` String NOT NULL
)
USING delta
"""
)
result_df = spark.sql(f"""
INSERT
INTO `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers` (
     `bg_sourcesystem`
    ,`bg_loadtimestamp`
    ,`bg_updatetimestamp`
    ,`ent_customers_id`
    ,`customer_id`
    ,`email_address`
    ,`full_name`
    ,`email_address1`
    ,`full_name1`
)
SELECT
     'Unknown' AS `bg_sourcesystem`
    ,'1900-01-01' AS `bg_loadtimestamp`
    ,'1900-01-01' AS `bg_updatetimestamp`
    ,-1 AS `ent_customers_id`
    ,0 AS `customer_id`
    ,'Unknown' AS `email_address`
    ,'Unknown' AS `full_name`
    ,'Unknown' AS `email_address1`
    ,'Unknown' AS `full_name1`
""")

# %%
# EntityLookupView: Ent_customers_Entity Lookup View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers_lookup`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address` AS `email_address`
    ,`bg_source`.`full_name` AS `full_name`
    ,`bg_source`.`email_address1` AS `email_address1`
    ,`bg_source`.`full_name1` AS `full_name1`
FROM `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_customers_result` AS `bg_source`
""")

# %%
# EntityResultView: Ent_customers_Entity Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers_result`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_updatetimestamp` AS `bg_updatetimestamp`
    ,`bg_source`.`ent_customers_id` AS `ent_customers_id`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address` AS `email_address`
    ,`bg_source`.`full_name` AS `full_name`
    ,`bg_source`.`email_address1` AS `email_address1`
    ,`bg_source`.`full_name1` AS `full_name1`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers` AS `bg_source`
""")

# %%
# EntityDeltaView: Ent_customers_Entity Delta View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers_delta`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address` AS `email_address`
    ,`bg_source`.`full_name` AS `full_name`
    ,`bg_source`.`email_address1` AS `email_address1`
    ,`bg_source`.`full_name1` AS `full_name1`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers_lookup` AS `bg_source`
LEFT OUTER JOIN `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers_result` AS `bg_target`
   ON (`bg_source`.`customer_id` = `bg_target`.`customer_id`)
  AND (`bg_source`.`email_address` = `bg_target`.`email_address`)
  AND (`bg_source`.`full_name` = `bg_target`.`full_name`)
WHERE `bg_target`.`ent_customers_id` IS NULL
""")

# %%
# MartDimensionTable: Ent_customers_Mart Dimension Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_rowhash` String
    ,`ent_customers_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`customer_id` Integer NOT NULL
    ,`email_address1` String NOT NULL
    ,`full_name1` String NOT NULL
)
USING delta
"""
)
result_df = spark.sql(f"""
INSERT
INTO `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers` (
     `bg_sourcesystem`
    ,`bg_loadtimestamp`
    ,`bg_rowhash`
    ,`ent_customers_id`
    ,`customer_id`
    ,`email_address1`
    ,`full_name1`
)
SELECT
     'Unknown' AS `bg_sourcesystem`
    ,'1900-01-01' AS `bg_loadtimestamp`
    ,'0' AS `bg_rowhash`
    ,-1 AS `ent_customers_id`
    ,0 AS `customer_id`
    ,'Unknown' AS `email_address1`
    ,'Unknown' AS `full_name1`
""")

# %%
# MartDimensionSourceView: Ent_customers_Mart Dimension Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers_source`
AS
SELECT
     CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`customer_id` AS `customer_id`
    ,`s1`.`email_address1` AS `email_address1`
    ,`s1`.`full_name1` AS `full_name1`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers_result` AS `s1`
""")

# %%
# MartDimensionHashingView: Ent_customers_Mart Dimension Hashing View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers_hashing`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,SHA2(COALESCE(`email_address1`, '_NULL_') || '_' || COALESCE(`full_name1`, '_NULL_'), 256) AS `bg_rowhash`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address1` AS `email_address1`
    ,`bg_source`.`full_name1` AS `full_name1`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers_source` AS `bg_source`
""")

# %%
# MartDimensionResultView: Ent_customers_Mart Dimension Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers_result`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_rowhash` AS `bg_rowhash`
    ,`bg_source`.`ent_customers_id` AS `ent_customers_id`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address1` AS `email_address1`
    ,`bg_source`.`full_name1` AS `full_name1`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers` AS `bg_source`
""")

# %%
# MartDimensionDeltaView: Ent_customers_Mart Dimension Delta View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers_delta`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_rowhash` AS `bg_rowhash`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address1` AS `email_address1`
    ,`bg_source`.`full_name1` AS `full_name1`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers_hashing` AS `bg_source`
LEFT OUTER JOIN `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers_result` AS `bg_target`
   ON (`bg_source`.`customer_id` = `bg_target`.`customer_id`)
  AND (`bg_source`.`bg_rowhash` = `bg_target`.`bg_rowhash`)
WHERE `bg_target`.`ent_customers_id` IS NULL
""")

# %%
# StageTable: customers_src_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_src`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_src` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`customer_id` Integer NOT NULL
    ,`email_address` String NOT NULL
    ,`full_name` String NOT NULL
    ,`city` String
)
USING delta
"""
)

# %%
# StageSourceView: customers_src_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_src_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`customer_id` AS `customer_id`
    ,`s1`.`email_address` AS `email_address`
    ,`s1`.`full_name` AS `full_name`
    ,`s1`.`city` AS `city`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`customers_src` AS `s1`
""")

# %%
# StageResultView: customers_src_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_src_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address` AS `email_address`
    ,`bg_source`.`full_name` AS `full_name`
    ,`bg_source`.`city` AS `city`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_src` AS `bg_source`
""")

# %%
# StageTable: customers_tgt_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_tgt`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_tgt` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`customer_id` Integer NOT NULL
    ,`email_address` String NOT NULL
    ,`full_name` String NOT NULL
)
USING delta
"""
)

# %%
# StageSourceView: customers_tgt_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_tgt_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`customer_id` AS `customer_id`
    ,`s1`.`email_address` AS `email_address`
    ,`s1`.`full_name` AS `full_name`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`customers_tgt` AS `s1`
""")

# %%
# StageResultView: customers_tgt_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_tgt_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address` AS `email_address`
    ,`bg_source`.`full_name` AS `full_name`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_tgt` AS `bg_source`
""")

# %%
# StageTable: inventory_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_inventory`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_inventory` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`inventory_id` Integer NOT NULL
    ,`store_id` Integer NOT NULL
    ,`product_id` Integer NOT NULL
    ,`product_inventory` Integer NOT NULL
)
USING delta
"""
)

# %%
# StageSourceView: inventory_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_inventory_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`inventory_id` AS `inventory_id`
    ,`s1`.`store_id` AS `store_id`
    ,`s1`.`product_id` AS `product_id`
    ,`s1`.`product_inventory` AS `product_inventory`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`inventory` AS `s1`
""")

# %%
# StageResultView: inventory_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_inventory_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`inventory_id` AS `inventory_id`
    ,`bg_source`.`store_id` AS `store_id`
    ,`bg_source`.`product_id` AS `product_id`
    ,`bg_source`.`product_inventory` AS `product_inventory`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_inventory` AS `bg_source`
""")

# %%
# StageTable: order_items_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_order_items`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_order_items` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`order_id` Integer NOT NULL
    ,`line_item_id` Integer NOT NULL
    ,`product_id` Integer NOT NULL
    ,`unit_price` Decimal(10,2) NOT NULL
    ,`quantity` Integer NOT NULL
    ,`shipment_id` Integer
)
USING delta
"""
)

# %%
# StageSourceView: order_items_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_order_items_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`order_id` AS `order_id`
    ,`s1`.`line_item_id` AS `line_item_id`
    ,`s1`.`product_id` AS `product_id`
    ,`s1`.`unit_price` AS `unit_price`
    ,`s1`.`quantity` AS `quantity`
    ,`s1`.`shipment_id` AS `shipment_id`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`order_items` AS `s1`
""")

# %%
# StageResultView: order_items_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_order_items_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`order_id` AS `order_id`
    ,`bg_source`.`line_item_id` AS `line_item_id`
    ,`bg_source`.`product_id` AS `product_id`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`quantity` AS `quantity`
    ,`bg_source`.`shipment_id` AS `shipment_id`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_order_items` AS `bg_source`
""")

# %%
# StageTable: orders_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_orders`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_orders` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`order_id` Integer NOT NULL
    ,`order_tms` Timestamp NOT NULL
    ,`customer_id` Integer NOT NULL
    ,`order_status` String NOT NULL
    ,`store_id` Integer NOT NULL
)
USING delta
"""
)

# %%
# StageSourceView: orders_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_orders_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`order_id` AS `order_id`
    ,`s1`.`order_tms` AS `order_tms`
    ,`s1`.`customer_id` AS `customer_id`
    ,`s1`.`order_status` AS `order_status`
    ,`s1`.`store_id` AS `store_id`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`orders` AS `s1`
""")

# %%
# StageResultView: orders_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_orders_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`order_id` AS `order_id`
    ,`bg_source`.`order_tms` AS `order_tms`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`store_id` AS `store_id`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_orders` AS `bg_source`
""")

# %%
# StageTable: product_orders_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_orders`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_orders` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`product_name` String NOT NULL
    ,`order_status` String NOT NULL
    ,`total_sales` Decimal(38,2)
    ,`order_count` Integer
)
USING delta
"""
)

# %%
# StageSourceView: product_orders_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_orders_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`product_name` AS `product_name`
    ,`s1`.`order_status` AS `order_status`
    ,`s1`.`total_sales` AS `total_sales`
    ,`s1`.`order_count` AS `order_count`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`product_orders` AS `s1`
""")

# %%
# StageResultView: product_orders_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_orders_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`product_name` AS `product_name`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`total_sales` AS `total_sales`
    ,`bg_source`.`order_count` AS `order_count`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_orders` AS `bg_source`
""")

# %%
# StageTable: product_reviews_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_reviews`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_reviews` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`product_name` String NOT NULL
    ,`rating` Integer
    ,`avg_rating` Integer
    ,`review` String
)
USING delta
"""
)

# %%
# StageSourceView: product_reviews_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_reviews_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`product_name` AS `product_name`
    ,`s1`.`rating` AS `rating`
    ,`s1`.`avg_rating` AS `avg_rating`
    ,`s1`.`review` AS `review`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`product_reviews` AS `s1`
""")

# %%
# StageResultView: product_reviews_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_reviews_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`product_name` AS `product_name`
    ,`bg_source`.`rating` AS `rating`
    ,`bg_source`.`avg_rating` AS `avg_rating`
    ,`bg_source`.`review` AS `review`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_reviews` AS `bg_source`
""")

# %%
# StageTable: products_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_products`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_products` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`product_id` Integer NOT NULL
    ,`product_name` String NOT NULL
    ,`unit_price` Decimal(10,2)
    ,`product_details` Binary
    ,`product_image` Binary
    ,`image_mime_type` String
    ,`image_filename` String
    ,`image_charset` String
    ,`image_last_updated` Timestamp
)
USING delta
"""
)

# %%
# StageSourceView: products_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_products_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`product_id` AS `product_id`
    ,`s1`.`product_name` AS `product_name`
    ,`s1`.`unit_price` AS `unit_price`
    ,`s1`.`product_details` AS `product_details`
    ,`s1`.`product_image` AS `product_image`
    ,`s1`.`image_mime_type` AS `image_mime_type`
    ,`s1`.`image_filename` AS `image_filename`
    ,`s1`.`image_charset` AS `image_charset`
    ,`s1`.`image_last_updated` AS `image_last_updated`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`products` AS `s1`
""")

# %%
# StageResultView: products_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_products_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`product_id` AS `product_id`
    ,`bg_source`.`product_name` AS `product_name`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`product_details` AS `product_details`
    ,`bg_source`.`product_image` AS `product_image`
    ,`bg_source`.`image_mime_type` AS `image_mime_type`
    ,`bg_source`.`image_filename` AS `image_filename`
    ,`bg_source`.`image_charset` AS `image_charset`
    ,`bg_source`.`image_last_updated` AS `image_last_updated`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_products` AS `bg_source`
""")

# %%
# EntityCleanseTable: Ent_products_Entity Cleanse Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_products`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_products` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp
    ,`bg_errorcount` Integer NOT NULL
    ,`bg_effectivetimestamp` Timestamp
    ,`bg_cleanse_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`product_id` Integer
    ,`product_name` String
    ,`unit_price` Decimal(10,2)
    ,`product_image` Binary
)
USING delta
"""
)

# %%
# EntityCleanseError: Ent_products_Entity Cleanse Error_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_products_error`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_products_error` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp
    ,`bg_errorcount` Integer NOT NULL
    ,`bg_errordescription` String
    ,`bg_effectivetimestamp` Timestamp
    ,`bg_cleanse_id` Long NOT NULL
    ,`product_id` Integer
    ,`product_name` String
    ,`unit_price` Decimal(10,2)
    ,`product_image` Binary
)
USING delta
"""
)

# %%
# EntitySourceView: Ent_products_Entity Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_products_source`
AS
SELECT
     CAST(NULL AS String) AS `bg_sourcesystem`
    ,current_timestamp() AS `bg_effectivetimestamp`
    ,`s1`.`product_id` AS `product_id`
    ,`s1`.`product_name` AS `product_name`
    ,`s1`.`unit_price` AS `unit_price`
    ,`s1`.`product_image` AS `product_image`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_products_result` AS `s1`
""")

# %%
# EntityIntermediateCleanseResultView: Ent_products_Entity Cleanse IntermediateResult View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_products_result`
AS
SELECT
     `bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`product_id` AS `product_id`
    ,`product_name` AS `product_name`
    ,`unit_price` AS `unit_price`
    ,`product_image` AS `product_image`
FROM `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_products`
WHERE `bg_errorcount` = 0
""")

# %%
# EntityCoreTable: Ent_products_Entity Core Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_updatetimestamp` Timestamp NOT NULL
    ,`ent_products_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`product_id` Integer NOT NULL
    ,`product_name` String NOT NULL
    ,`unit_price` Decimal(10,2) NOT NULL
    ,`product_image` Binary NOT NULL
)
USING delta
"""
)
result_df = spark.sql(f"""
INSERT
INTO `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products` (
     `bg_sourcesystem`
    ,`bg_loadtimestamp`
    ,`bg_updatetimestamp`
    ,`ent_products_id`
    ,`product_id`
    ,`product_name`
    ,`unit_price`
    ,`product_image`
)
SELECT
     'Unknown' AS `bg_sourcesystem`
    ,'1900-01-01' AS `bg_loadtimestamp`
    ,'1900-01-01' AS `bg_updatetimestamp`
    ,-1 AS `ent_products_id`
    ,0 AS `product_id`
    ,'Unknown' AS `product_name`
    ,0 AS `unit_price`
    ,0 AS `product_image`
""")

# %%
# EntityLookupView: Ent_products_Entity Lookup View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products_lookup`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`bg_source`.`product_id` AS `product_id`
    ,`bg_source`.`product_name` AS `product_name`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`product_image` AS `product_image`
FROM `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_products_result` AS `bg_source`
""")

# %%
# EntityResultView: Ent_products_Entity Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products_result`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_updatetimestamp` AS `bg_updatetimestamp`
    ,`bg_source`.`ent_products_id` AS `ent_products_id`
    ,`bg_source`.`product_id` AS `product_id`
    ,`bg_source`.`product_name` AS `product_name`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`product_image` AS `product_image`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products` AS `bg_source`
""")

# %%
# EntityDeltaView: Ent_products_Entity Delta View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products_delta`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`product_id` AS `product_id`
    ,`bg_source`.`product_name` AS `product_name`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`product_image` AS `product_image`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products_lookup` AS `bg_source`
LEFT OUTER JOIN `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products_result` AS `bg_target`
   ON (`bg_source`.`product_id` = `bg_target`.`product_id`)
  AND (`bg_source`.`product_name` = `bg_target`.`product_name`)
  AND (`bg_source`.`unit_price` = `bg_target`.`unit_price`)
  AND (`bg_source`.`product_image` = `bg_target`.`product_image`)
WHERE `bg_target`.`ent_products_id` IS NULL
""")

# %%
# MartDimensionTable: Ent_products_Mart Dimension Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_rowhash` String
    ,`ent_products_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`product_id` Integer NOT NULL
)
USING delta
"""
)
result_df = spark.sql(f"""
INSERT
INTO `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products` (
     `bg_sourcesystem`
    ,`bg_loadtimestamp`
    ,`bg_rowhash`
    ,`ent_products_id`
    ,`product_id`
)
SELECT
     'Unknown' AS `bg_sourcesystem`
    ,'1900-01-01' AS `bg_loadtimestamp`
    ,'0' AS `bg_rowhash`
    ,-1 AS `ent_products_id`
    ,0 AS `product_id`
""")

# %%
# MartDimensionSourceView: Ent_products_Mart Dimension Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products_source`
AS
SELECT
     CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`product_id` AS `product_id`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products_result` AS `s1`
""")

# %%
# MartDimensionHashingView: Ent_products_Mart Dimension Hashing View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products_hashing`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,'0' AS `bg_rowhash`
    ,`bg_source`.`product_id` AS `product_id`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products_source` AS `bg_source`
""")

# %%
# MartDimensionResultView: Ent_products_Mart Dimension Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products_result`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_rowhash` AS `bg_rowhash`
    ,`bg_source`.`ent_products_id` AS `ent_products_id`
    ,`bg_source`.`product_id` AS `product_id`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products` AS `bg_source`
""")

# %%
# MartDimensionDeltaView: Ent_products_Mart Dimension Delta View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products_delta`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_rowhash` AS `bg_rowhash`
    ,`bg_source`.`product_id` AS `product_id`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products_hashing` AS `bg_source`
LEFT OUTER JOIN `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products_result` AS `bg_target`
   ON (`bg_source`.`product_id` = `bg_target`.`product_id`)
  AND (`bg_source`.`bg_rowhash` = `bg_target`.`bg_rowhash`)
WHERE `bg_target`.`ent_products_id` IS NULL
""")

# %%
# StageTable: shipments_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_shipments`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_shipments` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`shipment_id` Integer NOT NULL
    ,`store_id` Integer NOT NULL
    ,`customer_id` Integer NOT NULL
    ,`delivery_address` String NOT NULL
    ,`shipment_status` String NOT NULL
)
USING delta
"""
)

# %%
# StageSourceView: shipments_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_shipments_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`shipment_id` AS `shipment_id`
    ,`s1`.`store_id` AS `store_id`
    ,`s1`.`customer_id` AS `customer_id`
    ,`s1`.`delivery_address` AS `delivery_address`
    ,`s1`.`shipment_status` AS `shipment_status`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`shipments` AS `s1`
""")

# %%
# StageResultView: shipments_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_shipments_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`shipment_id` AS `shipment_id`
    ,`bg_source`.`store_id` AS `store_id`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`delivery_address` AS `delivery_address`
    ,`bg_source`.`shipment_status` AS `shipment_status`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_shipments` AS `bg_source`
""")

# %%
# StageTable: store_orders_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_store_orders`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_store_orders` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`total` String
    ,`store_name` String
    ,`address` String
    ,`latitude` Decimal(9,6)
    ,`longitude` Decimal(9,6)
    ,`order_status` String
    ,`order_count` Integer
    ,`total_sales` Decimal(38,2)
)
USING delta
"""
)

# %%
# StageSourceView: store_orders_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_store_orders_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`total` AS `total`
    ,`s1`.`store_name` AS `store_name`
    ,`s1`.`address` AS `address`
    ,`s1`.`latitude` AS `latitude`
    ,`s1`.`longitude` AS `longitude`
    ,`s1`.`order_status` AS `order_status`
    ,`s1`.`order_count` AS `order_count`
    ,`s1`.`total_sales` AS `total_sales`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`store_orders` AS `s1`
""")

# %%
# StageResultView: store_orders_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_store_orders_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`total` AS `total`
    ,`bg_source`.`store_name` AS `store_name`
    ,`bg_source`.`address` AS `address`
    ,`bg_source`.`latitude` AS `latitude`
    ,`bg_source`.`longitude` AS `longitude`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`order_count` AS `order_count`
    ,`bg_source`.`total_sales` AS `total_sales`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_store_orders` AS `bg_source`
""")

# %%
# StageTable: stores_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_stores`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_stores` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`store_id` Integer NOT NULL
    ,`store_name` String NOT NULL
    ,`web_address` String
    ,`physical_address` String
    ,`latitude` Decimal(9,6)
    ,`longitude` Decimal(9,6)
    ,`logo` Binary
    ,`logo_mime_type` String
    ,`logo_filename` String
    ,`logo_charset` String
    ,`logo_last_updated` Timestamp
)
USING delta
"""
)

# %%
# StageSourceView: stores_Stage Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_stores_source`
AS
SELECT
     CAST(NULL AS Timestamp) AS `bg_loadtimestamp`
    ,CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`store_id` AS `store_id`
    ,`s1`.`store_name` AS `store_name`
    ,`s1`.`web_address` AS `web_address`
    ,`s1`.`physical_address` AS `physical_address`
    ,`s1`.`latitude` AS `latitude`
    ,`s1`.`longitude` AS `longitude`
    ,`s1`.`logo` AS `logo`
    ,`s1`.`logo_mime_type` AS `logo_mime_type`
    ,`s1`.`logo_filename` AS `logo_filename`
    ,`s1`.`logo_charset` AS `logo_charset`
    ,`s1`.`logo_last_updated` AS `logo_last_updated`
FROM `{marc_databricks_initiative#localsqlserver#database_name}`.`{marc_databricks_initiative#localsqlserver#schema_name}`.`stores` AS `s1`
""")

# %%
# StageResultView: stores_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_stores_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`store_id` AS `store_id`
    ,`bg_source`.`store_name` AS `store_name`
    ,`bg_source`.`web_address` AS `web_address`
    ,`bg_source`.`physical_address` AS `physical_address`
    ,`bg_source`.`latitude` AS `latitude`
    ,`bg_source`.`longitude` AS `longitude`
    ,`bg_source`.`logo` AS `logo`
    ,`bg_source`.`logo_mime_type` AS `logo_mime_type`
    ,`bg_source`.`logo_filename` AS `logo_filename`
    ,`bg_source`.`logo_charset` AS `logo_charset`
    ,`bg_source`.`logo_last_updated` AS `logo_last_updated`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_stores` AS `bg_source`
""")

# %%
# EntityCleanseTable: Ent_stores_Entity Cleanse Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_stores`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_stores` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp
    ,`bg_errorcount` Integer NOT NULL
    ,`bg_effectivetimestamp` Timestamp
    ,`bg_cleanse_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`store_name` String
    ,`web_address` String
    ,`latitude` Decimal(9,6)
    ,`longitude` Decimal(9,6)
    ,`physical_address` String
    ,`store_id` Integer
)
USING delta
"""
)

# %%
# EntityCleanseError: Ent_stores_Entity Cleanse Error_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_stores_error`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_stores_error` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp
    ,`bg_errorcount` Integer NOT NULL
    ,`bg_errordescription` String
    ,`bg_effectivetimestamp` Timestamp
    ,`bg_cleanse_id` Long NOT NULL
    ,`store_name` String
    ,`web_address` String
    ,`latitude` Decimal(9,6)
    ,`longitude` Decimal(9,6)
    ,`physical_address` String
    ,`store_id` Integer
)
USING delta
"""
)

# %%
# EntitySourceView: Ent_stores_Entity Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_stores_source`
AS
SELECT
     CAST(NULL AS String) AS `bg_sourcesystem`
    ,current_timestamp() AS `bg_effectivetimestamp`
    ,`s1`.`store_name` AS `store_name`
    ,`s1`.`web_address` AS `web_address`
    ,`s1`.`latitude` AS `latitude`
    ,`s1`.`longitude` AS `longitude`
    ,`s1`.`physical_address` AS `physical_address`
    ,`s1`.`store_id` AS `store_id`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_stores_result` AS `s1`
""")

# %%
# EntityIntermediateCleanseResultView: Ent_stores_Entity Cleanse IntermediateResult View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_stores_result`
AS
SELECT
     `bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`store_name` AS `store_name`
    ,`web_address` AS `web_address`
    ,`latitude` AS `latitude`
    ,`longitude` AS `longitude`
    ,`physical_address` AS `physical_address`
    ,`store_id` AS `store_id`
FROM `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_stores`
WHERE `bg_errorcount` = 0
""")

# %%
# EntityCoreTable: Ent_stores_Entity Core Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_updatetimestamp` Timestamp NOT NULL
    ,`ent_stores_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`store_name` String NOT NULL
    ,`web_address` String NOT NULL
    ,`latitude` Decimal(9,6) NOT NULL
    ,`longitude` Decimal(9,6) NOT NULL
    ,`physical_address` String NOT NULL
    ,`store_id` Integer NOT NULL
)
USING delta
"""
)
result_df = spark.sql(f"""
INSERT
INTO `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores` (
     `bg_sourcesystem`
    ,`bg_loadtimestamp`
    ,`bg_updatetimestamp`
    ,`ent_stores_id`
    ,`store_name`
    ,`web_address`
    ,`latitude`
    ,`longitude`
    ,`physical_address`
    ,`store_id`
)
SELECT
     'Unknown' AS `bg_sourcesystem`
    ,'1900-01-01' AS `bg_loadtimestamp`
    ,'1900-01-01' AS `bg_updatetimestamp`
    ,-1 AS `ent_stores_id`
    ,'Unknown' AS `store_name`
    ,'Unknown' AS `web_address`
    ,0 AS `latitude`
    ,0 AS `longitude`
    ,'Unknown' AS `physical_address`
    ,0 AS `store_id`
""")

# %%
# EntityLookupView: Ent_stores_Entity Lookup View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores_lookup`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`bg_source`.`store_name` AS `store_name`
    ,`bg_source`.`web_address` AS `web_address`
    ,`bg_source`.`latitude` AS `latitude`
    ,`bg_source`.`longitude` AS `longitude`
    ,`bg_source`.`physical_address` AS `physical_address`
    ,`bg_source`.`store_id` AS `store_id`
FROM `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_stores_result` AS `bg_source`
""")

# %%
# EntityResultView: Ent_stores_Entity Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores_result`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_updatetimestamp` AS `bg_updatetimestamp`
    ,`bg_source`.`ent_stores_id` AS `ent_stores_id`
    ,`bg_source`.`store_name` AS `store_name`
    ,`bg_source`.`web_address` AS `web_address`
    ,`bg_source`.`latitude` AS `latitude`
    ,`bg_source`.`longitude` AS `longitude`
    ,`bg_source`.`physical_address` AS `physical_address`
    ,`bg_source`.`store_id` AS `store_id`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores` AS `bg_source`
""")

# %%
# EntityDeltaView: Ent_stores_Entity Delta View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores_delta`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`store_name` AS `store_name`
    ,`bg_source`.`web_address` AS `web_address`
    ,`bg_source`.`latitude` AS `latitude`
    ,`bg_source`.`longitude` AS `longitude`
    ,`bg_source`.`physical_address` AS `physical_address`
    ,`bg_source`.`store_id` AS `store_id`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores_lookup` AS `bg_source`
LEFT OUTER JOIN `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores_result` AS `bg_target`
   ON (`bg_source`.`store_name` = `bg_target`.`store_name`)
  AND (`bg_source`.`web_address` = `bg_target`.`web_address`)
  AND (`bg_source`.`latitude` = `bg_target`.`latitude`)
  AND (`bg_source`.`longitude` = `bg_target`.`longitude`)
  AND (`bg_source`.`physical_address` = `bg_target`.`physical_address`)
  AND (`bg_source`.`store_id` = `bg_target`.`store_id`)
WHERE `bg_target`.`ent_stores_id` IS NULL
""")

# %%
# MartDimensionTable: Ent_stores_Mart Dimension Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores` (
     `bg_sourcesystem` String
    ,`bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_rowhash` String
    ,`ent_stores_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`store_id` Integer NOT NULL
)
USING delta
"""
)
result_df = spark.sql(f"""
INSERT
INTO `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores` (
     `bg_sourcesystem`
    ,`bg_loadtimestamp`
    ,`bg_rowhash`
    ,`ent_stores_id`
    ,`store_id`
)
SELECT
     'Unknown' AS `bg_sourcesystem`
    ,'1900-01-01' AS `bg_loadtimestamp`
    ,'0' AS `bg_rowhash`
    ,-1 AS `ent_stores_id`
    ,0 AS `store_id`
""")

# %%
# MartDimensionSourceView: Ent_stores_Mart Dimension Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores_source`
AS
SELECT
     CAST(NULL AS String) AS `bg_sourcesystem`
    ,`s1`.`store_id` AS `store_id`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores_result` AS `s1`
""")

# %%
# MartDimensionHashingView: Ent_stores_Mart Dimension Hashing View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores_hashing`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,'0' AS `bg_rowhash`
    ,`bg_source`.`store_id` AS `store_id`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores_source` AS `bg_source`
""")

# %%
# MartDimensionResultView: Ent_stores_Mart Dimension Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores_result`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_rowhash` AS `bg_rowhash`
    ,`bg_source`.`ent_stores_id` AS `ent_stores_id`
    ,`bg_source`.`store_id` AS `store_id`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores` AS `bg_source`
""")

# %%
# MartDimensionDeltaView: Ent_stores_Mart Dimension Delta View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores_delta`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_rowhash` AS `bg_rowhash`
    ,`bg_source`.`store_id` AS `store_id`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores_hashing` AS `bg_source`
LEFT OUTER JOIN `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores_result` AS `bg_target`
   ON (`bg_source`.`store_id` = `bg_target`.`store_id`)
  AND (`bg_source`.`bg_rowhash` = `bg_target`.`bg_rowhash`)
WHERE `bg_target`.`ent_stores_id` IS NULL
""")

# %%
# FactCleanseTable: order_items_Fact Cleanse Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_f_order_items`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_f_order_items` (
     `bg_errorcount` Integer NOT NULL
    ,`bg_errordescription` String
    ,`bg_loadtimestamp` Timestamp
    ,`bg_sourcesystem` String
    ,`bg_effectivetimestamp` Timestamp
    ,`bg_cleanse_id` Long NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1)
    ,`fk_ent_orders_order_id` Integer
    ,`fk_ent_orders_order_status` String
    ,`fk_ent_orders_order_total` Decimal(38,2)
    ,`fk_ent_customers_customer_id` Integer
    ,`fk_ent_customers_email_address` String
    ,`fk_ent_customers_full_name` String
    ,`fk_ent_products_product_id` Integer
    ,`fk_ent_products_product_name` String
    ,`fk_ent_products_unit_price` Decimal(10,2)
    ,`fk_ent_products_product_image` Binary
    ,`fk_ent_stores_store_name` String
    ,`fk_ent_stores_web_address` String
    ,`fk_ent_stores_latitude` Decimal(9,6)
    ,`fk_ent_stores_longitude` Decimal(9,6)
    ,`fk_ent_stores_physical_address` String
    ,`fk_ent_stores_store_id` Integer
    ,`unit_price` Decimal(10,2)
    ,`quantity` Integer
)
USING delta
"""
)

# %%
# FactCleanseError: order_items_Fact Cleanse Error_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_f_order_items_error`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_f_order_items_error` (
     `bg_errorcount` Integer NOT NULL
    ,`bg_errordescription` String
    ,`bg_loadtimestamp` Timestamp
    ,`bg_sourcesystem` String
    ,`bg_effectivetimestamp` Timestamp
    ,`bg_cleanse_id` Long NOT NULL
    ,`fk_ent_orders_order_id` Integer
    ,`fk_ent_orders_order_status` String
    ,`fk_ent_orders_order_total` Decimal(38,2)
    ,`fk_ent_customers_customer_id` Integer
    ,`fk_ent_customers_email_address` String
    ,`fk_ent_customers_full_name` String
    ,`fk_ent_products_product_id` Integer
    ,`fk_ent_products_product_name` String
    ,`fk_ent_products_unit_price` Decimal(10,2)
    ,`fk_ent_products_product_image` Binary
    ,`fk_ent_stores_store_name` String
    ,`fk_ent_stores_web_address` String
    ,`fk_ent_stores_latitude` Decimal(9,6)
    ,`fk_ent_stores_longitude` Decimal(9,6)
    ,`fk_ent_stores_physical_address` String
    ,`fk_ent_stores_store_id` Integer
    ,`unit_price` Decimal(10,2)
    ,`quantity` Integer
)
USING delta
"""
)

# %%
# FactSourceView: order_items_Fact Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_f_order_items_source`
AS
SELECT
     CAST(NULL AS String) AS `bg_sourcesystem`
    ,current_timestamp() AS `bg_effectivetimestamp`
    ,`s1`.`order_id` AS `fk_ent_orders_order_id`
    ,CAST(NULL AS String) AS `fk_ent_orders_order_status`
    ,CAST(NULL AS Decimal(38,2)) AS `fk_ent_orders_order_total`
    ,`s2`.`customer_id` AS `fk_ent_customers_customer_id`
    ,CAST(NULL AS String) AS `fk_ent_customers_email_address`
    ,CAST(NULL AS String) AS `fk_ent_customers_full_name`
    ,`s1`.`product_id` AS `fk_ent_products_product_id`
    ,CAST(NULL AS String) AS `fk_ent_products_product_name`
    ,CAST(NULL AS Decimal(10,2)) AS `fk_ent_products_unit_price`
    ,CAST(NULL AS Binary) AS `fk_ent_products_product_image`
    ,CAST(NULL AS String) AS `fk_ent_stores_store_name`
    ,CAST(NULL AS String) AS `fk_ent_stores_web_address`
    ,CAST(NULL AS Decimal(9,6)) AS `fk_ent_stores_latitude`
    ,CAST(NULL AS Decimal(9,6)) AS `fk_ent_stores_longitude`
    ,CAST(NULL AS String) AS `fk_ent_stores_physical_address`
    ,`s3`.`store_id` AS `fk_ent_stores_store_id`
    ,`s1`.`unit_price` AS `unit_price`
    ,`s1`.`quantity` AS `quantity`
FROM `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_order_items_result` AS `s1`
JOIN `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_result` AS `s2`
JOIN `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_stores_result` AS `s3`
""")

# %%
# FactCleanseIntermediateResultView: order_items_Fact Cleanse IntermediateResult View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_f_order_items_result`
AS
SELECT
     `bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`fk_ent_orders_order_id` AS `fk_ent_orders_order_id`
    ,`fk_ent_orders_order_status` AS `fk_ent_orders_order_status`
    ,`fk_ent_orders_order_total` AS `fk_ent_orders_order_total`
    ,`fk_ent_customers_customer_id` AS `fk_ent_customers_customer_id`
    ,`fk_ent_customers_email_address` AS `fk_ent_customers_email_address`
    ,`fk_ent_customers_full_name` AS `fk_ent_customers_full_name`
    ,`fk_ent_products_product_id` AS `fk_ent_products_product_id`
    ,`fk_ent_products_product_name` AS `fk_ent_products_product_name`
    ,`fk_ent_products_unit_price` AS `fk_ent_products_unit_price`
    ,`fk_ent_products_product_image` AS `fk_ent_products_product_image`
    ,`fk_ent_stores_store_name` AS `fk_ent_stores_store_name`
    ,`fk_ent_stores_web_address` AS `fk_ent_stores_web_address`
    ,`fk_ent_stores_latitude` AS `fk_ent_stores_latitude`
    ,`fk_ent_stores_longitude` AS `fk_ent_stores_longitude`
    ,`fk_ent_stores_physical_address` AS `fk_ent_stores_physical_address`
    ,`fk_ent_stores_store_id` AS `fk_ent_stores_store_id`
    ,`unit_price` AS `unit_price`
    ,`quantity` AS `quantity`
FROM `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_f_order_items`
WHERE `bg_errorcount` = 0
""")

# %%
# FactCoreTable: order_items_Fact Core Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_f_order_items`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_f_order_items` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`ent_orders_ent_orders_id` Long NOT NULL
    ,`ent_customers_ent_customers_id` Long NOT NULL
    ,`ent_products_ent_products_id` Long NOT NULL
    ,`ent_stores_ent_stores_id` Long NOT NULL
    ,`unit_price` Decimal(10,2) NOT NULL
    ,`quantity` Integer NOT NULL
)
USING delta
"""
)

# %%
# FactLookupView: order_items_Fact Lookup View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_f_order_items_lookup`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`quantity` AS `quantity`
    ,COALESCE(`r1`.`ent_orders_id`, -1) AS `ent_orders_ent_orders_id`
    ,COALESCE(`r2`.`ent_customers_id`, -1) AS `ent_customers_ent_customers_id`
    ,COALESCE(`r3`.`ent_products_id`, -1) AS `ent_products_ent_products_id`
    ,COALESCE(`r4`.`ent_stores_id`, -1) AS `ent_stores_ent_stores_id`
FROM `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_f_order_items_result` AS `bg_source`
LEFT OUTER JOIN `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders_result` AS `r1`
   ON (`r1`.`order_id` = `bg_source`.`fk_ent_orders_order_id`)
  AND (`r1`.`order_status` = `bg_source`.`fk_ent_orders_order_status`)
  AND (`r1`.`order_total` = `bg_source`.`fk_ent_orders_order_total`)
LEFT OUTER JOIN `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers_result` AS `r2`
   ON (`r2`.`customer_id` = `bg_source`.`fk_ent_customers_customer_id`)
  AND (`r2`.`email_address` = `bg_source`.`fk_ent_customers_email_address`)
  AND (`r2`.`full_name` = `bg_source`.`fk_ent_customers_full_name`)
LEFT OUTER JOIN `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products_result` AS `r3`
   ON (`r3`.`product_id` = `bg_source`.`fk_ent_products_product_id`)
  AND (`r3`.`product_name` = `bg_source`.`fk_ent_products_product_name`)
  AND (`r3`.`unit_price` = `bg_source`.`fk_ent_products_unit_price`)
  AND (`r3`.`product_image` = `bg_source`.`fk_ent_products_product_image`)
LEFT OUTER JOIN `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores_result` AS `r4`
   ON (`r4`.`store_name` = `bg_source`.`fk_ent_stores_store_name`)
  AND (`r4`.`web_address` = `bg_source`.`fk_ent_stores_web_address`)
  AND (`r4`.`latitude` = `bg_source`.`fk_ent_stores_latitude`)
  AND (`r4`.`longitude` = `bg_source`.`fk_ent_stores_longitude`)
  AND (`r4`.`physical_address` = `bg_source`.`fk_ent_stores_physical_address`)
  AND (`r4`.`store_id` = `bg_source`.`fk_ent_stores_store_id`)
""")

# %%
# FactResultView: order_items_Fact Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_f_order_items_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`ent_orders_ent_orders_id` AS `ent_orders_ent_orders_id`
    ,`bg_source`.`ent_customers_ent_customers_id` AS `ent_customers_ent_customers_id`
    ,`bg_source`.`ent_products_ent_products_id` AS `ent_products_ent_products_id`
    ,`bg_source`.`ent_stores_ent_stores_id` AS `ent_stores_ent_stores_id`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`quantity` AS `quantity`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_f_order_items` AS `bg_source`
""")

# %%
# MartFactTable: order_items_Mart Fact Table_1
spark.sql("""DROP TABLE IF EXISTS `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_mf_order_items`""")

spark.sql("""CREATE TABLE `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_mf_order_items` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`ent_customers_ent_customers_id` Long NOT NULL
    ,`ent_orders_ent_orders_id` Long NOT NULL
    ,`ent_products_ent_products_id` Long NOT NULL
    ,`ent_stores_ent_stores_id` Long NOT NULL
    ,`unit_price` Decimal(10,2) NOT NULL
    ,`quantity` Integer NOT NULL
)
USING delta
"""
)

# %%
# MartFactSourceView: order_items_Mart Fact Source View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_mf_order_items_source`
AS
SELECT
     CAST(NULL AS String) AS `bg_sourcesystem`
    ,current_timestamp() AS `bg_effectivetimestamp`
    ,CAST(`s1`.`ent_customers_ent_customers_id` AS Integer) AS `fk_ent_customers_customer_id`
    ,CAST(`s1`.`ent_orders_ent_orders_id` AS Integer) AS `fk_ent_orders_order_id`
    ,CAST(`s1`.`ent_products_ent_products_id` AS Integer) AS `fk_ent_products_product_id`
    ,CAST(`s1`.`ent_stores_ent_stores_id` AS Integer) AS `fk_ent_stores_store_id`
    ,`s1`.`unit_price` AS `unit_price`
    ,`s1`.`quantity` AS `quantity`
FROM `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_f_order_items_result` AS `s1`
""")

# %%
# MartFactLookupView: order_items_Mart Fact Lookup View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_mf_order_items_lkp`
AS
SELECT
     `bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`bg_effectivetimestamp` AS `bg_effectivetimestamp`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`quantity` AS `quantity`
    ,COALESCE(`r1`.`ent_customers_id`, -1) AS `ent_customers_ent_customers_id`
    ,COALESCE(`r2`.`ent_orders_id`, -1) AS `ent_orders_ent_orders_id`
    ,COALESCE(`r3`.`ent_products_id`, -1) AS `ent_products_ent_products_id`
    ,COALESCE(`r4`.`ent_stores_id`, -1) AS `ent_stores_ent_stores_id`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_mf_order_items_source` AS `bg_source`
LEFT OUTER JOIN `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers_result` AS `r1`
   ON (`r1`.`customer_id` = `bg_source`.`fk_ent_customers_customer_id`)
LEFT OUTER JOIN `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders_result` AS `r2`
   ON (`r2`.`order_id` = `bg_source`.`fk_ent_orders_order_id`)
LEFT OUTER JOIN `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products_result` AS `r3`
   ON (`r3`.`product_id` = `bg_source`.`fk_ent_products_product_id`)
LEFT OUTER JOIN `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores_result` AS `r4`
   ON (`r4`.`store_id` = `bg_source`.`fk_ent_stores_store_id`)
""")

# %%
# MartFactResultView: order_items_Mart Fact Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_mf_order_items_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`ent_customers_ent_customers_id` AS `ent_customers_ent_customers_id`
    ,`bg_source`.`ent_orders_ent_orders_id` AS `ent_orders_ent_orders_id`
    ,`bg_source`.`ent_products_ent_products_id` AS `ent_products_ent_products_id`
    ,`bg_source`.`ent_stores_ent_stores_id` AS `ent_stores_ent_stores_id`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`quantity` AS `quantity`
FROM `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_mf_order_items` AS `bg_source`
""")

# %%
# MartFooter

# %%
# CoreFooter

# %%
# CleanseFooter

# %%
# StageFooter
