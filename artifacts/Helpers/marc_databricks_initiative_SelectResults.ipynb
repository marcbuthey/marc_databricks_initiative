# %%
df = spark.sql("""
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_orders_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_orders_result`
    union
    select '`{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_stores_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_stores_result`
    union
    select '`{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_stores_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products1_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products1_result`
    union
    select '`{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_products_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_tgt_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_tgt_result`
    union
    select '`{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_stores_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_result`
    union
    select '`{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_mf_order_items_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_mf_order_items_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_inventory_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_inventory_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_orders_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_orders_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_shipments_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_shipments_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_products_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_products_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customer_order_products_result`
    union
    select '`{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_orders_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_orders_result`
    union
    select '`{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_orders_result`
    union
    select '`{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_products_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_products_result`
    union
    select '`{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_products_result`
    union
    select '`{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_f_order_items_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_f_order_items_result`
    union
    select '`{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_f_order_items_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_f_order_items_result`
    union
    select '`{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_orders_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_src_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_customers_src_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_stores_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_stores_result`
    union
    select '`{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_customers_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#cleanse#database_name}`.`{marc_databricks_initiative#cleanse#schema_name}`.`cls_en_ent_customers_result`
    union
    select '`{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#core#database_name}`.`{marc_databricks_initiative#core#schema_name}`.`cor_en_ent_customers_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_reviews_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_product_reviews_result`
    union
    select '`{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#mart#database_name}`.`{marc_databricks_initiative#mart#schema_name}`.`dm_md_ent_customers_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_store_orders_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_store_orders_result`
    union
    select '`{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_order_items_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{marc_databricks_initiative#stage#database_name}`.`{marc_databricks_initiative#stage#schema_name}`.`stg_st_order_items_result`
""")
df.show(n=1000, truncate=False)
